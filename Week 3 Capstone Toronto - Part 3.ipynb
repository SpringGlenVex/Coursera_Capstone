# %% [markdown]
# <h1 align=center><font size = 5>Capstone Week 3 - Segmenting and Clustering Neighborhoods in Toronto</font></h1>

# %% [markdown]
# ## Part 3 - Clustering the Neighborhoods
# explore and cluster the neighborhoods in Toronto.

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item1">Part 1 - Data Scraping of Neighborhood Names and Postal Codes</a>
#
# 2. <a href="#item2">Part 2 - Get Latitue and Longitude Coordinates of Neighborhoods</a>
#
# 3. <a href="#item3">Part 3 - Clustering the Neighborhoods</a>
#
# </font>
# </div>

# %% [markdown]
# Before we get the data and start exploring it, let's download all the dependencies that we will need.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# used for scraping
import requests
from bs4 import BeautifulSoup
import matplotlib.colors as colors

#!conda install -c conda-forge geocoder --yes # uncomment this line if you haven't completed the Foursquare API lab
import geocoder # import geocoder

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %% [markdown]
# <a id='item1'></a>

# %% [markdown]
# ## 1. Download and Explore Dataset

# %%
# Get the json from wikipedia and read it with beautiful soup
res = requests.get(" https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")
soup = BeautifulSoup(res.content,'lxml')
table = soup.find_all('table')[0] 
df = pd.read_html(str(table))

# The wikipedia page is not really a table, it's more like a matrix.  Concatenate all the text into a single column
df=df[0]
frames = [df.iloc[:,0],df.iloc[:,1],df.iloc[:,2],df.iloc[:,3],df.iloc[:,4],df.iloc[:,5],df.iloc[:,6],df.iloc[:,7]]
df = pd.concat(frames)
df = df.to_frame()
df.reset_index(inplace = True, drop=True) # Fix the indices
df.columns = ['raw']

# get rid of rows for postal codes that aren't assigned
df = df[~df.raw.str.contains("Not assigned")]
df = df[~df.raw.str.contains("Queen's Park")] # This gets rid of Queen's Park, which is mostly a government center, so not interesting to us here.
df = df[~df.raw.str.contains("Upper Rouge")] # This gets rid of Upper Rouge, which is a wilderness area, so not interesting to us here.
df = df[~df.raw.str.contains("Newtonbrook")] # This gets rid of Newtonbrook.  It's a distant exurb, and for some reason foursquare doesn't find any venues there, so I'm removing it.


# Ditch the "enclaves" too.  They're related to bulk mailing, and not interesting for the purposes of this analysis, which is centered on fun places to live.  
# Also they don't follow exactly the same format and mess up the cleaning process.
df = df[~df.raw.str.contains("Enclave")]
df.reset_index(inplace = True, drop=True)

# The dataframe has only a single column that has all the data kludged together.  Regex would probably be prettier, but let's pull the data out without it...
# Postal code is the first three letters
df['Postal Code'] = df['raw'].str[:3] 
df['raw'] = df['raw'].str[3:-1] # -1 removes the closing parentheses that we don't need

# now split up the neighborhood and boroughs
df[['Borough','Neighborhood']]=df.raw.str.split("(",n=1,expand=True,)
del df["raw"]

# %% [markdown]
# ## 2. Get geolocation data

# %%
# Read the provided CSV, and convert to a dataframe
# I probably spent three hours trying to get the coordinates the hard way, and just came up empty.  Even the code provided by an instructor on the discussion boards didn't work for me. Sad.
# !wget -O Geospatial_Coordiantes.csv http://cocl.us/Geospatial_data
locationDF = pd.read_csv("Geospatial_Coordiantes.csv")
# Out:
# --2020-03-23 02:22:18--  http://cocl.us/Geospatial_data
# Resolving cocl.us (cocl.us)... 158.85.108.83, 158.85.108.86, 169.48.113.194
# Connecting to cocl.us (cocl.us)|158.85.108.83|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://cocl.us/Geospatial_data [following]
# --2020-03-23 02:22:20--  https://cocl.us/Geospatial_data
# Connecting to cocl.us (cocl.us)|158.85.108.83|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-03-23 02:22:23--  https://ibm.box.com/shared/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.box.com (ibm.box.com)... 107.152.27.197, 107.152.26.197
# Connecting to ibm.box.com (ibm.box.com)|107.152.27.197|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-03-23 02:22:24--  https://ibm.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Reusing existing connection to ibm.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv [following]
# --2020-03-23 02:22:24--  https://ibm.ent.box.com/public/static/9afzr83pps4pwf2smjjcf1y5mvgb18rr.csv
# Resolving ibm.ent.box.com (ibm.ent.box.com)... 107.152.26.211, 107.152.27.211
# Connecting to ibm.ent.box.com (ibm.ent.box.com)|107.152.26.211|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://public.boxcloud.com/d/1/b1!KXE58tMBCTIQKTYTpn12gCqkaqngeaiD_68JZ0TaH0tg1ym7KoBeaJIO2fqdwxnQqbW68-_QSnsQaziSnw1kvuDf0bT5d-7JUCK6WK3pxm0ZtXn3suKvszH2V1A4QrjeXVWIUUQasJIBuPF-eTzXXc2eXGfKp8HwshQTYcHBfFYSK-NP9SILp_qIpIezfUrgh0oLPuzmze43F6UU4zHSYWpgBDpzCxDb181Q-jO1rU02KMCWOYJDEoRib5N5FkXOkhn3ZGRNIK9lzj9xRPq8SPLHqqLpvZAhVUr3VlHZFVFp0i0cBO4fsmc6obdekAc9k5CFN1S8BLfy_dbVOyO2_la14VVkF29JWAmWwXYdMNtOYPOY6-RzJbXTQWYsNMHmNiY2anApojCa25hpx47S4mFeF-59fS6qLpUsiUQjFQ5kW4Px-A54mzE9K_LTt2SZuS2cIfBYcuekpSBZYwe7_VHa-8pnNCGgLGxLgwuKrx2k4ja1JYeEPR43YyT8pZjyps1Vve0miOxoTgW9-uAuu3yOJnpYJwqn3-MSQCu9YmPFHPu6JRqBJXG2p78h1_rmzfZy8u_JonrI-65BMfWHXrzOx9ASF-50MjNi_B_G71ZtzhU-gsCN-dkBYSOhHh4aN0JdN-KOCfJFkoc3np5rXd6cROw5BKN9PxNF0Na7mPr6IzP45uCvQGZt2k4GRw346JyNwbZ9kHYTpBgKcUyCQa91vw3DhsrmR-m9YGpCBWnMfZCEDJHCSDYok-fwqScCw7yp4kMsfdcIP52VFAtZvPgu37GAHKghgoa710_Ppb8-UK21hyuMLukp6jSx2Fz3oMkGvqQXgAmjhwxBvDBvPO-iNlRflEEo8XBuT0vSrxWrHzExu0iSsR92sKBsZDjCwHpLCmohcJ2_FGNZBMoGDKzFj4z0TCm_obJdcvzYRmFP8igVUBqgtT-YJUpgGSfYkBFZGB6u76nrTM14z6cmz5-YkDM1qGzrUZJhUsooc89rylpmkOWHuLczUYji1iG4po49H5NzCHtUS2L963bQIQWnp7mFNWLg6mybkm6yUVVDOCURbb-z02IOwWRXACgNbKyiZxlX9c4sxPvHkiNXaUJaYNsVyolC8wNrxEceb1zQ1JMppuSBMYdKCST3BDWYilUY01XJEJFaB5QGZsrV5Km91_BAdHiywlmXUR4PErzPAK_lqfiGurNGU8WMomBOIpchm5gFOsJZ0a5aDvI6QIdx1Nag3ocUft2LFVSItnq4jRJfpFF1C8y_EGFtedMIG7qkjUKUTcFlLju1s0U1FLu9U6U-jxZ5HWKVuBQu0Apo74kk10q12-nSRGuk53lUddvsr7XSG_6pUm5dbCkAlHfa7FzD11GADt6hyKhozBiN4n-CqPXLXlEwc5M./download [following]
# --2020-03-23 02:22:24--  https://public.boxcloud.com/d/1/b1!KXE58tMBCTIQKTYTpn12gCqkaqngeaiD_68JZ0TaH0tg1ym7KoBeaJIO2fqdwxnQqbW68-_QSnsQaziSnw1kvuDf0bT5d-7JUCK6WK3pxm0ZtXn3suKvszH2V1A4QrjeXVWIUUQasJIBuPF-eTzXXc2eXGfKp8HwshQTYcHBfFYSK-NP9SILp_qIpIezfUrgh0oLPuzmze43F6UU4zHSYWpgBDpzCxDb181Q-jO1rU02KMCWOYJDEoRib5N5FkXOkhn3ZGRNIK9lzj9xRPq8SPLHqqLpvZAhVUr3VlHZFVFp0i0cBO4fsmc6obdekAc9k5CFN1S8BLfy_dbVOyO2_la14VVkF29JWAmWwXYdMNtOYPOY6-RzJbXTQWYsNMHmNiY2anApojCa25hpx47S4mFeF-59fS6qLpUsiUQjFQ5kW4Px-A54mzE9K_LTt2SZuS2cIfBYcuekpSBZYwe7_VHa-8pnNCGgLGxLgwuKrx2k4ja1JYeEPR43YyT8pZjyps1Vve0miOxoTgW9-uAuu3yOJnpYJwqn3-MSQCu9YmPFHPu6JRqBJXG2p78h1_rmzfZy8u_JonrI-65BMfWHXrzOx9ASF-50MjNi_B_G71ZtzhU-gsCN-dkBYSOhHh4aN0JdN-KOCfJFkoc3np5rXd6cROw5BKN9PxNF0Na7mPr6IzP45uCvQGZt2k4GRw346JyNwbZ9kHYTpBgKcUyCQa91vw3DhsrmR-m9YGpCBWnMfZCEDJHCSDYok-fwqScCw7yp4kMsfdcIP52VFAtZvPgu37GAHKghgoa710_Ppb8-UK21hyuMLukp6jSx2Fz3oMkGvqQXgAmjhwxBvDBvPO-iNlRflEEo8XBuT0vSrxWrHzExu0iSsR92sKBsZDjCwHpLCmohcJ2_FGNZBMoGDKzFj4z0TCm_obJdcvzYRmFP8igVUBqgtT-YJUpgGSfYkBFZGB6u76nrTM14z6cmz5-YkDM1qGzrUZJhUsooc89rylpmkOWHuLczUYji1iG4po49H5NzCHtUS2L963bQIQWnp7mFNWLg6mybkm6yUVVDOCURbb-z02IOwWRXACgNbKyiZxlX9c4sxPvHkiNXaUJaYNsVyolC8wNrxEceb1zQ1JMppuSBMYdKCST3BDWYilUY01XJEJFaB5QGZsrV5Km91_BAdHiywlmXUR4PErzPAK_lqfiGurNGU8WMomBOIpchm5gFOsJZ0a5aDvI6QIdx1Nag3ocUft2LFVSItnq4jRJfpFF1C8y_EGFtedMIG7qkjUKUTcFlLju1s0U1FLu9U6U-jxZ5HWKVuBQu0Apo74kk10q12-nSRGuk53lUddvsr7XSG_6pUm5dbCkAlHfa7FzD11GADt6hyKhozBiN4n-CqPXLXlEwc5M./download
# Resolving public.boxcloud.com (public.boxcloud.com)... 107.152.25.200
# Connecting to public.boxcloud.com (public.boxcloud.com)|107.152.25.200|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/csv]
# Saving to: ‘Geospatial_Coordiantes.csv’
#
# 100%[======================================>] 2,891       --.-K/s   in 0s
#
# 2020-03-23 02:22:25 (245 MB/s) - ‘Geospatial_Coordiantes.csv’ saved [2891/2891]

# %% [markdown]
# ### Merge the location data with the postal code data from Part 1

# %%
df = pd.merge(df, locationDF, on='Postal Code')

# %% [markdown]
# ## 3. Cluster the Neighborhoods

# %%
df.head()
# Out:
#   Postal Code      Borough                              Neighborhood  \
# 0         M1B  Scarborough                           Malvern / Rouge
# 1         M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2         M1E  Scarborough       Guildwood / Morningside / West Hill
# 3         M1G  Scarborough                                    Woburn
# 4         M1H  Scarborough                                 Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# #### Use geopy library to get the latitude and longitude values of Toronto.

# %% [markdown]
# In order to define an instance of the geocoder, we need to define a user_agent. We will name our agent <em>ny_explorer</em>, as shown below.

# %%
address = 'Toronto, ON'
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

geolocator = Nominatim(user_agent="Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### Create a map of New York with neighborhoods superimposed on top.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df['Latitude'], df['Longitude'], df['Borough'], df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
# @hidden cell
CLIENT_ID = 'WJ53105PC20DYM2B5NH5TBDPOBP5D4CP2B4VS3ANCZDEGHNV' # your Foursquare ID
CLIENT_SECRET = 'MEQHUTWXJLBAOH1FITA0X02NJCNL5K3QTHFZSGBMIWGMD0NW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: WJ53105PC20DYM2B5NH5TBDPOBP5D4CP2B4VS3ANCZDEGHNV
# CLIENT_SECRET:MEQHUTWXJLBAOH1FITA0X02NJCNL5K3QTHFZSGBMIWGMD0NW

# %% [markdown]
# From the Foursquare lab in the previous module, we know that all the information is in the *items* key. Before we proceed, let's borrow the **get_category_type** function from the Foursquare lab.

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Let's create a function to repeat the same process to all the neighborhoods in Manhattan

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    LIMIT = 100 # limit of number of venues returned by Foursquare API
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Now write the code to run the above function on each neighborhood and create a new dataframe called manhattan_venues.¶

# %%
toronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Malvern / Rouge
# Rouge Hill / Port Union / Highland Creek
# Guildwood / Morningside / West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park / Ionview / East Birchmount Park
# Golden Mile / Clairlea / Oakridge
# Cliffside / Cliffcrest / Scarborough Village West
# Birch Cliff / Cliffside West
# Dorset Park / Wexford Heights / Scarborough Town Centre
# Wexford / Maryvale
# Agincourt
# Clarks Corners / Tam O'Shanter / Sullivan
# Milliken / Agincourt North / Steeles East / L'Amoreaux East
# Steeles West / L'Amoreaux West
# Hillcrest Village
# Fairview / Henry Farm / Oriole
# Bayview Village
# York Mills / Silver Hills
# Willowdale)Sout
# York Mills West
# Willowdale)Wes
# Parkwoods
# Don Mills)Nort
# Don Mills)South(Flemingdon Park
# Bathurst Manor / Wilson Heights / Downsview North
# Northwood Park / York University
# Downsview)East (CFB Toronto
# Downsview)Wes
# Downsview)Centra
# Downsview)Northwes
# Victoria Village
# Parkview Hill / Woodbine Gardens
# Woodbine Heights
# The Beaches
# Leaside
# Thorncliffe Park
# The Danforth East
# The Danforth West / Riverdale
# India Bazaar / The Beaches West
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park / Summerhill East
# Summerhill West / Rathnelly / South Hill / Forest Hill SE / Deer Park
# Rosedale
# St. James Town / Cabbagetown
# Church and Wellesley
# Regent Park / Harbourfront
# Garden District, Ryerson
# St. James Town
# Berczy Park
# Central Bay Street
# Richmond / Adelaide / King
# Harbourfront East / Union Station / Toronto Islands
# Toronto Dominion Centre / Design Exchange
# Commerce Court / Victoria Hotel
# Bedford Park / Lawrence Manor East
# Roselawn
# Forest Hill North & West
# The Annex / North Midtown / Yorkville
# University of Toronto / Harbord
# Kensington Market / Chinatown / Grange Park
# CN Tower / King and Spadina / Railway Lands / Harbourfront West / Bathurst Quay / South Niagara / Island airport
# First Canadian Place / Underground city
# Lawrence Manor / Lawrence Heights
# Glencairn
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Christie
# Dufferin / Dovercourt Village
# Little Portugal / Trinity
# Brockton / Parkdale Village / Exhibition Place
# North Park / Maple Leaf Park / Upwood Park
# Del Ray / Mount Dennis / Keelsdale and Silverthorn
# Runnymede / The Junction North
# High Park / The Junction South
# Parkdale / Roncesvalles
# Runnymede / Swansea
# New Toronto / Mimico South / Humber Bay Shores
# Alderwood / Long Branch
# The Kingsway / Montgomery Road / Old Mill North
# Old Mill South / King's Mill Park / Sunnylea / Humber Bay / Mimico NE / The Queensway East / Royal York South East / Kingsway Park South East
# Mimico NW / The Queensway West / South of Bloor / Kingsway Park South West / Royal York South West

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 264 uniques categories.

# %% [markdown]
# ### Analyze Each Neighborhood

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# %% [markdown]
# ### Next, let's group rows by neighborhood and by taking the mean of the frequency of occurrence of each category

# %%
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# ### Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    #print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    #print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    #print('\n')

# %% [markdown]
# Let's put that into a pandas dataframe
#
# First, let's write a function to sort the venues in descending order.

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# Now let's create the new dataframe and display the top 10 venues for each neighborhood.

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                         Neighborhood 1st Most Common Venue  \
# 0                                          Agincourt        Breakfast Spot
# 1                            Alderwood / Long Branch           Pizza Place
# 2  Bathurst Manor / Wilson Heights / Downsview North                  Bank
# 3                                    Bayview Village    Chinese Restaurant
# 4                 Bedford Park / Lawrence Manor East    Italian Restaurant
#
#   2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0          Skating Rink  Latin American Restaurant        Clothing Store
# 1           Coffee Shop             Sandwich Place          Skating Rink
# 2           Coffee Shop         Frozen Yogurt Shop      Sushi Restaurant
# 3                  Café        Japanese Restaurant                  Bank
# 4           Coffee Shop                 Restaurant        Sandwich Place
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0                Lounge               Dog Run    Dim Sum Restaurant
# 1                  Pool              Pharmacy                   Pub
# 2        Ice Cream Shop         Deli / Bodega           Pizza Place
# 3               Dog Run    Dim Sum Restaurant                 Diner
# 4         Grocery Store              Pharmacy          Liquor Store
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                 Diner        Discount Store    Distribution Center
# 1                   Gym   Distribution Center         Discount Store
# 2              Pharmacy            Restaurant            Supermarket
# 3        Discount Store   Distribution Center          Women's Store
# 4     Indian Restaurant        Ice Cream Shop   Fast Food Restaurant

# %% [markdown]
# ### Cluster Neighborhoods

# %% [markdown]
# Run k-means to cluster the neighborhood into 5 clusters.
# I picked 9 because the largest group has 42 neighborhoods.  With other choices the largest group always had more
# Even with 30 groups, the largest group still has 35 neighborhoods.  They must be very homogeneous...

# %%
# set number of clusters
kclusters = 9

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# Inspect the number of neighborhoods placed in each group.  We don't want too many single-neighborhood groups
y = np.bincount(kmeans.labels_)
ii = np.nonzero(y)[0]
groupSize = np.vstack((ii,y[ii])).T

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each neighborhood.

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
#   Postal Code      Borough                              Neighborhood  \
# 0         M1B  Scarborough                           Malvern / Rouge
# 1         M1C  Scarborough  Rouge Hill / Port Union / Highland Creek
# 2         M1E  Scarborough       Guildwood / Morningside / West Hill
# 3         M1G  Scarborough                                    Woburn
# 4         M1H  Scarborough                                 Cedarbrae
#
#     Latitude  Longitude  Cluster Labels 1st Most Common Venue  \
# 0  43.806686 -79.194353               6  Fast Food Restaurant
# 1  43.784535 -79.160497               7                   Bar
# 2  43.763573 -79.188711               0     Electronics Store
# 3  43.770992 -79.216917               1           Coffee Shop
# 4  43.773136 -79.239476               0    Athletics & Sports
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0         Women's Store         Deli / Bodega   Empanada Restaurant
# 1         Women's Store         Deli / Bodega   Empanada Restaurant
# 2        Breakfast Spot        Medical Center                  Bank
# 3          Soccer Field     Korean Restaurant       College Stadium
# 4  Caribbean Restaurant                Bakery                  Bank
#
#   5th Most Common Venue        6th Most Common Venue 7th Most Common Venue  \
# 0     Electronics Store  Eastern European Restaurant   Dumpling Restaurant
# 1     Electronics Store  Eastern European Restaurant   Dumpling Restaurant
# 2    Mexican Restaurant                 Intersection   Rental Car Location
# 3  Colombian Restaurant          Empanada Restaurant     Electronics Store
# 4   Fried Chicken Joint              Thai Restaurant           Gas Station
#
#          8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0                   Donut Shop      Doner Restaurant                Dog Run
# 1                   Donut Shop      Doner Restaurant                Dog Run
# 2                          Spa      Doner Restaurant             Donut Shop
# 3  Eastern European Restaurant   Dumpling Restaurant             Donut Shop
# 4             Hakka Restaurant      Doner Restaurant                Dog Run

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examine Clusters

# %% [markdown]
# Now, you can examine each cluster and determine the discriminating venue categories that distinguish each cluster. Based on the defining categories, you can then assign a name to each cluster.

# %% [markdown]
# #### Cluster 1

# %% [markdown]
# This cluster is of neighborhoods pretty far from downtown.  Lots of banks, discount stores, electronic stores, pharmacies, grocery stores, pizza places, diner
# ### I call it boring suburbia

# %%
print('This cluster has '+ str(groupSize[0,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 15 neighborhoods
#          Borough  Cluster Labels 1st Most Common Venue  \
# 2    Scarborough               0     Electronics Store
# 4    Scarborough               0    Athletics & Sports
# 11   Scarborough               0           Auto Garage
# 12   Scarborough               0        Breakfast Spot
# 13   Scarborough               0           Pizza Place
# 15   Scarborough               0  Fast Food Restaurant
# 16    North York               0           Golf Course
# 18    North York               0    Chinese Restaurant
# 22    North York               0         Grocery Store
# 29    North York               0         Grocery Store
# 30    North York               0      Business Service
# 33     East York               0           Pizza Place
# 73  West Toronto               0                Bakery
# 78          York               0         Grocery Store
# 85     Etobicoke               0             Locksmith
#
#        2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 2             Breakfast Spot             Medical Center                  Bank
# 4       Caribbean Restaurant                     Bakery                  Bank
# 11                    Bakery              Shopping Mall        Sandwich Place
# 12              Skating Rink  Latin American Restaurant        Clothing Store
# 13                  Pharmacy               Intersection          Noodle House
# 15        Chinese Restaurant              Grocery Store        Sandwich Place
# 16  Mediterranean Restaurant                       Pool               Dog Run
# 18                      Café        Japanese Restaurant                  Bank
# 22                      Bank               Home Service        Discount Store
# 29                      Park              Shopping Mall                  Bank
# 30                Food Truck               Home Service        Baseball Field
# 33                  Pharmacy                  Gastropub                  Bank
# 73                  Pharmacy                Pizza Place         Grocery Store
# 78                   Brewery                   Bus Line     Convenience Store
# 85            Baseball Field              Women's Store      Department Store
#
#         5th Most Common Venue    6th Most Common Venue  \
# 2          Mexican Restaurant             Intersection
# 4         Fried Chicken Joint          Thai Restaurant
# 11             Breakfast Spot               Smoke Shop
# 12                     Lounge                  Dog Run
# 13              Shopping Mall              Gas Station
# 15                       Bank                 Pharmacy
# 16             Discount Store         Department Store
# 18                    Dog Run       Dim Sum Restaurant
# 22                   Pharmacy              Pizza Place
# 29                      Hotel  Comfort Food Restaurant
# 30           Department Store             Dessert Shop
# 33         Athletics & Sports                 Bus Line
# 73  Middle Eastern Restaurant                     Park
# 78         Dim Sum Restaurant                    Diner
# 85        Empanada Restaurant        Electronics Store
#
#           7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 2           Rental Car Location                   Spa      Doner Restaurant
# 4                   Gas Station      Hakka Restaurant      Doner Restaurant
# 11   Construction & Landscaping     Convenience Store  Colombian Restaurant
# 12           Dim Sum Restaurant                 Diner        Discount Store
# 13         Fast Food Restaurant    Italian Restaurant    Chinese Restaurant
# 15                  Pizza Place        Breakfast Spot           Coffee Shop
# 16                 Dessert Shop    Dim Sum Restaurant                 Diner
# 18                        Diner        Discount Store   Distribution Center
# 22                  Coffee Shop        Airport Lounge      Department Store
# 29                   Comic Shop       College Stadium     Electronics Store
# 30           Dim Sum Restaurant                 Diner        Discount Store
# 33                 Intersection                  Café  Fast Food Restaurant
# 73                         Pool                  Café               Brewery
# 78               Discount Store   Distribution Center               Dog Run
# 85  Eastern European Restaurant   Dumpling Restaurant            Donut Shop
#
#          10th Most Common Venue
# 2                    Donut Shop
# 4                       Dog Run
# 11          Empanada Restaurant
# 12          Distribution Center
# 13                         Bank
# 15                   Nail Salon
# 16          Distribution Center
# 18                Women's Store
# 22         Ethiopian Restaurant
# 29  Eastern European Restaurant
# 30                Women's Store
# 33         Gym / Fitness Center
# 73         Fast Food Restaurant
# 78             Doner Restaurant
# 85             Doner Restaurant

# %% [markdown]
# #### Cluster 2

# %% [markdown]
# This is a large group of neighborhoods.

# %% [markdown]
# They often have coffee shops, cafes, restaurants, (Italian, pizza, generic, bakery, desert, diner, bar, japanese etc.)

# %% [markdown]
# ### I call this a restaurant destination

# %%
print('This cluster has '+ str(groupSize[1,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 42 neighborhoods
#              Borough  Cluster Labels 1st Most Common Venue  \
# 3        Scarborough               1           Coffee Shop
# 6        Scarborough               1        Discount Store
# 9        Scarborough               1       College Stadium
# 14       Scarborough               1           Coffee Shop
# 17        North York               1        Clothing Store
# 20        North York               1      Ramen Restaurant
# 24        North York               1        Baseball Field
# 25        North York               1      Asian Restaurant
# 26        North York               1                  Bank
# 27        North York               1         Metro Station
# 31        North York               1         Grocery Store
# 32        North York               1           Coffee Shop
# 36         East York               1           Coffee Shop
# 39      East Toronto               1      Greek Restaurant
# 41      East Toronto               1                  Café
# 44   Central Toronto               1           Coffee Shop
# 45   Central Toronto               1        Sandwich Place
# 47   Central Toronto               1           Coffee Shop
# 49  Downtown Toronto               1            Restaurant
# 50  Downtown Toronto               1           Coffee Shop
# 51  Downtown Toronto               1           Coffee Shop
# 52  Downtown Toronto               1           Coffee Shop
# 53  Downtown Toronto               1           Coffee Shop
# 54  Downtown Toronto               1           Coffee Shop
# 55  Downtown Toronto               1           Coffee Shop
# 56  Downtown Toronto               1           Coffee Shop
# 57  Downtown Toronto               1           Coffee Shop
# 58  Downtown Toronto               1           Coffee Shop
# 59  Downtown Toronto               1           Coffee Shop
# 60        North York               1    Italian Restaurant
# 63   Central Toronto               1        Sandwich Place
# 64  Downtown Toronto               1                  Café
# 65  Downtown Toronto               1                   Bar
# 66  Downtown Toronto               1        Airport Lounge
# 67  Downtown Toronto               1           Coffee Shop
# 68        North York               1        Clothing Store
# 72  Downtown Toronto               1         Grocery Store
# 74      West Toronto               1                   Bar
# 75      West Toronto               1           Coffee Shop
# 79      West Toronto               1    Mexican Restaurant
# 80      West Toronto               1             Gift Shop
# 81      West Toronto               1           Pizza Place
#
#     2nd Most Common Venue      3rd Most Common Venue  \
# 3            Soccer Field          Korean Restaurant
# 6        Department Store                Coffee Shop
# 9            Skating Rink                       Café
# 14                   Park                     Bakery
# 17            Coffee Shop       Fast Food Restaurant
# 20             Restaurant                Pizza Place
# 24   Gym / Fitness Center                       Café
# 25             Restaurant                Coffee Shop
# 26            Coffee Shop         Frozen Yogurt Shop
# 27            Coffee Shop             Massage Studio
# 31            Coffee Shop               Liquor Store
# 32  Portuguese Restaurant               Hockey Arena
# 36    Sporting Goods Shop     Furniture / Home Store
# 39            Coffee Shop         Italian Restaurant
# 41            Coffee Shop        American Restaurant
# 44         Clothing Store                Yoga Studio
# 45           Dessert Shop                Pizza Place
# 47                    Pub        American Restaurant
# 49                 Bakery                Coffee Shop
# 50    Japanese Restaurant                    Gay Bar
# 51                   Park                        Pub
# 52         Clothing Store  Middle Eastern Restaurant
# 53                   Café                 Restaurant
# 54             Restaurant               Cocktail Bar
# 55     Italian Restaurant             Sandwich Place
# 56             Restaurant                       Café
# 57               Aquarium                       Café
# 58                  Hotel                       Café
# 59                   Café                 Restaurant
# 60            Coffee Shop                 Restaurant
# 63                   Café                Coffee Shop
# 64             Restaurant        Japanese Restaurant
# 65                   Café      Vietnamese Restaurant
# 66        Airport Service           Sculpture Garden
# 67                   Café                 Restaurant
# 68      Accessories Store                Coffee Shop
# 72                   Café                       Park
# 74            Coffee Shop                 Restaurant
# 75         Breakfast Spot                       Café
# 79                   Café                        Bar
# 80              Bookstore              Movie Theater
# 81                   Café                Coffee Shop
#
#             4th Most Common Venue    5th Most Common Venue  \
# 3                 College Stadium     Colombian Restaurant
# 6               Convenience Store               Hobby Shop
# 9           General Entertainment            Women's Store
# 14                     Playground      Distribution Center
# 17                  Women's Store                     Bank
# 20               Sushi Restaurant              Coffee Shop
# 24            Japanese Restaurant     Caribbean Restaurant
# 25                     Beer Store                      Gym
# 26               Sushi Restaurant           Ice Cream Shop
# 27                            Bar     Caribbean Restaurant
# 31             Athletics & Sports  Comfort Food Restaurant
# 32     Financial or Legal Service            Women's Store
# 36                           Bank             Burger Joint
# 39                      Bookstore           Ice Cream Shop
# 41                        Brewery                   Bakery
# 44                          Diner               Restaurant
# 45             Italian Restaurant                      Gym
# 47                   Burger Joint              Supermarket
# 49             Italian Restaurant              Pizza Place
# 50               Sushi Restaurant               Restaurant
# 51                         Bakery       Mexican Restaurant
# 52            Japanese Restaurant           Cosmetics Shop
# 53                          Hotel       Italian Restaurant
# 54                       Beer Bar                   Bakery
# 55                   Burger Joint      Japanese Restaurant
# 56                Thai Restaurant                      Bar
# 57             Italian Restaurant                    Hotel
# 58                     Restaurant       Seafood Restaurant
# 59                          Hotel      American Restaurant
# 60                 Sandwich Place            Grocery Store
# 63                            Pub      American Restaurant
# 64             Italian Restaurant                Bookstore
# 65  Vegetarian / Vegan Restaurant              Coffee Shop
# 66                    Coffee Shop          Harbor / Marina
# 67                     Steakhouse                Gastropub
# 68         Furniture / Home Store       Miscellaneous Shop
# 72                     Baby Store              Gas Station
# 74               Asian Restaurant              Men's Store
# 75                         Bakery                  Stadium
# 79                Thai Restaurant            Grocery Store
# 80                     Restaurant                      Bar
# 81               Sushi Restaurant       Italian Restaurant
#
#      6th Most Common Venue      7th Most Common Venue  \
# 3      Empanada Restaurant          Electronics Store
# 6                  Dog Run               Dessert Shop
# 9      Distribution Center               Dessert Shop
# 14        Department Store               Dessert Shop
# 17                  Bakery          Convenience Store
# 20          Sandwich Place                       Café
# 24           Women's Store         Dim Sum Restaurant
# 25     Sporting Goods Shop         Italian Restaurant
# 26           Deli / Bodega                Pizza Place
# 27          Discount Store               Dessert Shop
# 31              Comic Shop        Empanada Restaurant
# 32          Discount Store           Department Store
# 36           Grocery Store             Breakfast Spot
# 39  Furniture / Home Store              Grocery Store
# 41          Clothing Store         Italian Restaurant
# 44    Fast Food Restaurant               Dessert Shop
# 45                    Café           Sushi Restaurant
# 47                    Bank               Liquor Store
# 49                     Pub                       Park
# 50               Gastropub               Dance Studio
# 51                    Café                 Restaurant
# 52                    Café                    Theater
# 53          Cosmetics Shop                   Beer Bar
# 54          Farmers Market                Cheese Shop
# 55          Ice Cream Shop  Middle Eastern Restaurant
# 56              Steakhouse             Cosmetics Shop
# 57     Sporting Goods Shop             Scenic Lookout
# 58     American Restaurant        Japanese Restaurant
# 59                     Gym         Seafood Restaurant
# 60                Pharmacy               Liquor Store
# 63               BBQ Joint             History Museum
# 64                  Bakery                        Bar
# 65                  Bakery         Mexican Restaurant
# 66        Airport Terminal              Boat or Ferry
# 67        Asian Restaurant         Seafood Restaurant
# 68                Boutique                 Shoe Store
# 72      Italian Restaurant                      Diner
# 74                Wine Bar      Vietnamese Restaurant
# 75           Burrito Place                 Restaurant
# 79     Arts & Crafts Store                       Park
# 80        Cuban Restaurant                    Dog Run
# 81           Grocery Store          French Restaurant
#
#           8th Most Common Venue        9th Most Common Venue  \
# 3   Eastern European Restaurant          Dumpling Restaurant
# 6            Dim Sum Restaurant                        Diner
# 9            Dim Sum Restaurant                        Diner
# 14           Dim Sum Restaurant                        Diner
# 17               Cosmetics Shop             Toy / Game Store
# 20          Japanese Restaurant              Bubble Tea Shop
# 24                        Diner               Discount Store
# 25                    Bike Shop               Sandwich Place
# 26                     Pharmacy                   Restaurant
# 27           Dim Sum Restaurant                        Diner
# 31            Electronics Store  Eastern European Restaurant
# 32                 Dessert Shop           Dim Sum Restaurant
# 36                   Sports Bar                   Beer Store
# 39           Frozen Yogurt Shop                          Pub
# 41                         Bank             Stationery Store
# 44                         Café           Mexican Restaurant
# 45                  Coffee Shop             Greek Restaurant
# 47                  Pizza Place                   Sports Bar
# 49                         Café                      Butcher
# 50     Mediterranean Restaurant                  Men's Store
# 51                      Theater                  Yoga Studio
# 52         Fast Food Restaurant                  Pizza Place
# 53               Clothing Store                       Bakery
# 54                         Café           Seafood Restaurant
# 55                         Café                    Juice Bar
# 56                    Bookstore               Breakfast Spot
# 57                      Brewery                   Restaurant
# 58           Italian Restaurant                    Gastropub
# 59           Italian Restaurant                    Gastropub
# 60            Indian Restaurant               Ice Cream Shop
# 63                  Pizza Place                     Pharmacy
# 64                 Dessert Shop             Sushi Restaurant
# 65          Dumpling Restaurant      Comfort Food Restaurant
# 66                 Airport Gate                     Boutique
# 67                          Gym          Japanese Restaurant
# 68                  Event Space        Vietnamese Restaurant
# 72                    Nightclub                  Candy Store
# 74                  Pizza Place                         Café
# 75                    Pet Store        Performing Arts Venue
# 79    Cajun / Creole Restaurant                        Diner
# 80                 Dessert Shop           Italian Restaurant
# 81                          Pub    Latin American Restaurant
#
#          10th Most Common Venue
# 3                    Donut Shop
# 6           Distribution Center
# 9                Discount Store
# 14               Discount Store
# 17          Japanese Restaurant
# 20                Shopping Mall
# 24          Distribution Center
# 25                Grocery Store
# 26                  Supermarket
# 27          Distribution Center
# 31          Dumpling Restaurant
# 32                        Diner
# 36                Shopping Mall
# 39                  Pizza Place
# 41                          Bar
# 44          Sporting Goods Shop
# 45               Farmers Market
# 47          Fried Chicken Joint
# 49                         Bank
# 50                        Hotel
# 51                  Event Space
# 52                    Bookstore
# 53                        Diner
# 54                    Nightclub
# 55             Department Store
# 56           Seafood Restaurant
# 57          Fried Chicken Joint
# 58                          Bar
# 59                Deli / Bodega
# 60         Fast Food Restaurant
# 63                 Liquor Store
# 64                         Bank
# 65                 Dessert Shop
# 66           Airport Food Court
# 67                        Hotel
# 68  Eastern European Restaurant
# 72                   Restaurant
# 74                  Yoga Studio
# 75                 Climbing Gym
# 79                    Bookstore
# 80               Breakfast Spot
# 81                    Juice Bar

# %% [markdown]
# Cluster 3

# %%
print('This cluster has '+ str(groupSize[2,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 1 neighborhoods
#             Borough  Cluster Labels 1st Most Common Venue  \
# 61  Central Toronto               2                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 61         Women's Store   Distribution Center      Department Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 61          Dessert Shop    Dim Sum Restaurant                 Diner
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 61        Discount Store               Dog Run           Dance Studio

# %% [markdown]
# Cluster 4

# %% [markdown]
# Most of these neighborhoods feature lots of partks, plus dicount stores, women's stores, rivers, playgorounds, diners, Dim Sum and desserts

# %% [markdown]
# ### I call it parks and recreation

# %%
print('This cluster has '+ str(groupSize[3,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 8 neighborhoods
#                   Borough  Cluster Labels 1st Most Common Venue  \
# 21             North York               3                  Park
# 23             North York               3                  Park
# 28             North York               3                  Park
# 38  East YorkEast Toronto               3                  Park
# 48       Downtown Toronto               3                  Park
# 71                   York               3                  Park
# 76             North York               3                  Park
# 84              Etobicoke               3                  Park
#
#    2nd Most Common Venue       3rd Most Common Venue 4th Most Common Venue  \
# 21     Convenience Store                        Bank               Dog Run
# 23     Food & Drink Shop               Women's Store   Distribution Center
# 28               Airport               Women's Store               Dog Run
# 38     Convenience Store               Metro Station     Electronics Store
# 48                 Trail                  Playground         Deli / Bodega
# 71         Women's Store                      Market   Distribution Center
# 76                Bakery  Construction & Landscaping         Women's Store
# 84                 River               Women's Store        Discount Store
#
#           5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 21                 Dessert Shop    Dim Sum Restaurant                 Diner
# 23             Department Store          Dessert Shop    Dim Sum Restaurant
# 28             Department Store          Dessert Shop    Dim Sum Restaurant
# 38  Eastern European Restaurant   Dumpling Restaurant            Donut Shop
# 48             Department Store          Dessert Shop    Dim Sum Restaurant
# 71             Department Store          Dessert Shop    Dim Sum Restaurant
# 76                      Dog Run          Dessert Shop    Dim Sum Restaurant
# 84                Deli / Bodega      Department Store          Dessert Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 21        Discount Store   Distribution Center          Women's Store
# 23                 Diner        Discount Store                Dog Run
# 28                 Diner        Discount Store    Distribution Center
# 38      Doner Restaurant               Dog Run           Dance Studio
# 48                 Diner        Discount Store          Women's Store
# 71                 Diner        Discount Store                Dog Run
# 76                 Diner        Discount Store    Distribution Center
# 84    Dim Sum Restaurant                 Diner    Distribution Center

# %% [markdown]
# #### Cluster 5

# %% [markdown]
# A good balnace of restaurants and recreational activities.  A nice place to live?

# %%
print('This cluster has '+ str(groupSize[4,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 16 neighborhoods
#             Borough  Cluster Labels 1st Most Common Venue  \
# 7       Scarborough               4              Bus Line
# 8       Scarborough               4          Skating Rink
# 10      Scarborough               4     Indian Restaurant
# 34        East York               4          Skating Rink
# 35     East Toronto               4                   Pub
# 37        East York               4     Indian Restaurant
# 40     East Toronto               4            Board Shop
# 42  Central Toronto               4           Swim School
# 43  Central Toronto               4                 Hotel
# 46  Central Toronto               4                   Gym
# 62  Central Toronto               4                 Trail
# 69       North York               4                   Pub
# 77             York               4          Skating Rink
# 82        Etobicoke               4                Bakery
# 83        Etobicoke               4           Pizza Place
# 86        Etobicoke               4         Grocery Store
#
#     2nd Most Common Venue 3rd Most Common Venue        4th Most Common Venue  \
# 7                  Bakery          Intersection                Metro Station
# 8           Movie Theater                 Motel          American Restaurant
# 10  Vietnamese Restaurant             Pet Store           Chinese Restaurant
# 34               Pharmacy            Beer Store               Cosmetics Shop
# 35      Health Food Store                 Trail  Eastern European Restaurant
# 37          Grocery Store           Supermarket                         Bank
# 40            Pizza Place               Brewery                Movie Theater
# 42               Bus Line  Gym / Fitness Center                         Park
# 43   Gym / Fitness Center     Food & Drink Shop               Breakfast Spot
# 46                   Park          Tennis Court                   Playground
# 62          Jewelry Store                  Park             Sushi Restaurant
# 69                   Park      Sushi Restaurant          Japanese Restaurant
# 77   Fast Food Restaurant        Discount Store               Sandwich Place
# 82    Fried Chicken Joint                  Café             Business Service
# 83            Coffee Shop        Sandwich Place                 Skating Rink
# 86         Hardware Store       Supplement Shop               Discount Store
#
#    5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 7         Ice Cream Shop           Bus Station                     Park
# 8          Women's Store               Dog Run             Dessert Shop
# 10         Women's Store   Distribution Center         Department Store
# 34           Curling Ice                  Park  Comfort Food Restaurant
# 35   Dumpling Restaurant            Donut Shop         Doner Restaurant
# 37          Burger Joint           Coffee Shop     Fast Food Restaurant
# 40    Italian Restaurant            Restaurant            Burrito Place
# 42         Women's Store   Distribution Center             Dessert Shop
# 43                  Park        Sandwich Place                      Gym
# 46         Women's Store        Discount Store            Deli / Bodega
# 62   Distribution Center      Department Store             Dessert Shop
# 69         Women's Store        Discount Store         Department Store
# 77         Women's Store   Distribution Center         Department Store
# 82    Seafood Restaurant                   Gym             Liquor Store
# 83                  Pool              Pharmacy                      Pub
# 86         Burrito Place          Burger Joint        Convenience Store
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 7           Soccer Field            Donut Shop       Doner Restaurant
# 8     Dim Sum Restaurant                 Diner         Discount Store
# 10          Dessert Shop    Dim Sum Restaurant                  Diner
# 34      Department Store     Electronics Store        College Stadium
# 35               Dog Run   Distribution Center            Curling Ice
# 37           Gas Station                   Gym           Liquor Store
# 40        Ice Cream Shop  Fast Food Restaurant             Steakhouse
# 42    Dim Sum Restaurant                 Diner         Discount Store
# 43      Department Store   Dumpling Restaurant             Donut Shop
# 46      Department Store          Dessert Shop     Dim Sum Restaurant
# 62    Dim Sum Restaurant                 Diner         Discount Store
# 69          Dessert Shop    Dim Sum Restaurant                  Diner
# 77          Dessert Shop    Dim Sum Restaurant                  Diner
# 82  Fast Food Restaurant   American Restaurant             Restaurant
# 83                   Gym   Distribution Center         Discount Store
# 86  Fast Food Restaurant        Sandwich Place                    Gym

# %% [markdown]
# Cluster 6

# %%
print('This cluster has '+ str(groupSize[5,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 1 neighborhoods
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 19  North York               5             Cafeteria         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19   Distribution Center      Department Store          Dessert Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19    Dim Sum Restaurant                 Diner        Discount Store
#
#    9th Most Common Venue 10th Most Common Venue
# 19               Dog Run           Dance Studio

# %% [markdown]
# Cluster 7

# %%
print('This cluster has '+ str(groupSize[6,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 6, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 1 neighborhoods
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0  Scarborough               6  Fast Food Restaurant         Women's Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0         Deli / Bodega   Empanada Restaurant     Electronics Store
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0  Eastern European Restaurant   Dumpling Restaurant            Donut Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0      Doner Restaurant                Dog Run

# %% [markdown]
# Cluster 8

# %%
print('This cluster has '+ str(groupSize[7,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 7, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 1 neighborhoods
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough               7                   Bar         Women's Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1         Deli / Bodega   Empanada Restaurant     Electronics Store
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1  Eastern European Restaurant   Dumpling Restaurant            Donut Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 1      Doner Restaurant                Dog Run

# %% [markdown]
# Cluster 9

# %%
print('This cluster has '+ str(groupSize[8,1]) + ' neighborhoods')
toronto_merged.loc[toronto_merged['Cluster Labels'] == 8, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
# This cluster has 2 neighborhoods
#         Borough  Cluster Labels       1st Most Common Venue  \
# 5   Scarborough               8  Construction & Landscaping
# 70         York               8                       Trail
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 5             Playground      Doner Restaurant          Dessert Shop
# 70                 Field          Hockey Arena            Playground
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 5     Dim Sum Restaurant                 Diner        Discount Store
# 70   Distribution Center      Department Store          Dessert Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 5    Distribution Center               Dog Run          Women's Store
# 70    Dim Sum Restaurant                 Diner         Discount Store
